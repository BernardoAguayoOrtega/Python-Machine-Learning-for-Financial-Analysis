# %% [markdown]
# # 1. TEXT FILES

# %% [markdown]
# - open() is the key function to handle files
# - open() function takes two parameters: (1) filename (2) mode.
# - Modes for files opening:
#
#     - "r" - Read - Default value. Opens a file for reading, error if the file does not exist
#     - "a" - Append - Opens a file for appending, creates the file if it does not exist
#     - "w" - Write - Opens a file for writing, creates the file if it does not exist
#     - "x" - Create - Creates the specified file, returns an error if the file exists
#
# - files can be used in a binary or text mode
#
#     - "t" - Text - Default value. Text mode
#     - "b" - Binary - Binary mode (e.g. images)

# %%
# In order to access data on Google Drive, you need to mount the drive to access it's content

# %%
# Open and read text file
f = open('./sample_text_file.txt', 'r')
print(f.read())
# Out:
# I am learning python now!
# It is super fun to learn Python programming
# I am learning how to handle files in python!Now the file has more content!Now the file has more content!

# %%
# readline will be used to read the first line
f = open('./sample_text_file.txt', 'r')
print(f.readline())
print(f.readline())
# Out:
# I am learning python now!
#
# It is super fun to learn Python programming

# %%
# You can open the file and append content to it
f = open('./sample_text_file.txt', 'a')
f.write('Now the file has more content!')
# Out:
# 30

# %%
# close the file and let's check its content
f.close()

# %%
# Let's open the updated file after writing new content to it
with open('./sample_text_file.txt', 'r') as f:
    text_data = f.read()

# %%
text_data
# Out:
# 'I am learning python now!\nIt is super fun to learn Python programming \nI am learning how to handle files in python!Now the file has more content!Now the file has more content!Now the file has more content!'

# %%
# split into a list of words
for line in text_data.split('\n'):
    print(line.split())
# Out:
# ['I', 'am', 'learning', 'python', 'now!']
# ['It', 'is', 'super', 'fun', 'to', 'learn', 'Python', 'programming']
# ['I', 'am', 'learning', 'how', 'to', 'handle', 'files', 'in', 'python!Now', 'the', 'file', 'has', 'more', 'content!Now', 'the', 'file', 'has', 'more', 'content!Now', 'the', 'file', 'has', 'more', 'content!']

# %% [markdown]
# **MINI CHALLENGE #1:**
# - **Read the file 'fruits_input.txt'**
# - **compare the text file content to the list my_fruits = ["Apple", "Pepper", "Orange", "Watermelon", "Tomatoes"]**

# %%
f = open('./fruits_input.txt', 'r')
data = f.read().split('\n')

# %%
my_fruits = ["Apple", "Pepper", "Orange", "Watermelon", "Tomatoes"]

# %%
data = [f for f in data if f in my_fruits]
data
# Out:
# ['Apple', 'Watermelon', 'Orange']

# %% [markdown]
# # 2. CSV FILES

# %%
# you can read csv files using "csv.reader"

f = open('./sample_csv_file.csv', 'r')
f.read()
# Out:
# 'first, last, email, postal, gender, dollar\nJoseph,Patton,daafeja@boh.jm,M6U 5U7,Male,"$2,629.13 "\nNoah,Moran,guutodi@bigwoc.kw,K2D 4M9,Male,"$8,626.96 "\nNina,Keller,azikez@gahew.mr,S1T 4E6,Male,"$9,072.02 "\n'

# %%
# Let's view the data
import csv

with open('./sample_csv_file.csv', 'r') as f:
    csv_reader = csv.reader(f, delimiter=',')
    data = list(csv_reader)

# %%
# Let's view the first row
data[0]
# Out:
# ['first', ' last', ' email', ' postal', ' gender', ' dollar']

# %%
# Let's view the second row
data[1]
# Out:
# ['Joseph', 'Patton', 'daafeja@boh.jm', 'M6U 5U7', 'Male', '$2,629.13 ']

# %%
# Combine first and last names together to generate full_name
full_name = [row[0] + ' ' + row[1] for row in data[1:]]
full_name
# Out:
# ['Joseph Patton', 'Noah Moran', 'Nina Keller']

# %%
dollar = [row[5] for row in data[1:]]
dollar
# Out:
# ['$2,629.13 ', '$8,626.96 ', '$9,072.02 ']

# %% [markdown]
# **MINI CHALLENGE #2:**
# - **Read the CSV file entitled "S&P500_Stock_data.csv" and print out the heading**
# - **Print out the first 5 rows of data**

# %%
import csv

with open('./S_P500_Stock_Data.csv', 'r') as f:
    csv_reader = csv.reader(f, delimiter=',')
    data = list(csv_reader)

# %%
first_five = data[:6]
first_five
# Out:
# [['Interest Rates', 'Employment', 'S&P 500 Price'],
#  ['1.943859273', '55.41357113', '2206.680582'],
#  ['2.258228944', '59.54630512', '2486.474488'],
#  ['2.215862783', '57.41468676', '2405.868337'],
#  ['1.977959542', '49.90835272', '2140.434475'],
#  ['2.437722808', '52.03549192', '2411.275663']]

# %% [markdown]
# # EXCELLENT JOB!

# %% [markdown]
# # MINI CHALLENGE SOLUTIONS:

# %% [markdown]
# **MINI CHALLENGE #1:**
# - **Read the file 'fruits_input.txt'**
# - **compare the text file content to the list my_fruits = ["Apple", "Pepper", "Orange", "Watermelon", "Tomatoes"]**

# %%
my_fruits = ["Apple", "Pepper", "Orange", "Watermelon", "Tomatoes"]

with open("/content/drive/My Drive/Colab Notebooks/Python & ML in Finance/Part 1. Python Programming Fundamentals/fruits_input.txt", "r") as file:
    all_fruits = file.readlines()

all_fruits = [char.rstrip('\n') for char in all_fruits]
Selected_fruits = [i for i in all_fruits if i in my_fruits]

print(Selected_fruits)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 my_fruits = ["Apple", "Pepper", "Orange", "Watermelon", "Tomatoes"]
# ----> 3 with open("/content/drive/My Drive/Colab Notebooks/Python & ML in Finance/Part 1. Python Programming Fundamentals/fruits_input.txt", "r") as file:
#       4     all_fruits = file.readlines()
#       6 all_fruits = [char.rstrip('\n') for char in all_fruits]
#
# File ~/Documents/Python/Python-Machine-Learning-for-Financial-Analysis/Part 1. Python Programming Fundamentals/env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Python & ML in Finance/Part 1. Python Programming Fundamentals/fruits_input.txt'

# %% [markdown]
# **MINI CHALLENGE #2:**
# - **Read the CSV file entitled "S&P500_Stock_data.csv" and print out the heading**
# - **Print out the first 5 rows of data**

# %%
import csv
with open("/content/drive/My Drive/Colab Notebooks/Python & ML in Finance/Part 1. Python Programming Fundamentals/S&P500_Stock_Data.csv", "r") as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    stock = list(readCSV)

# %%
print(stock)

# %%
print(stock[0])

# %%
selected = []
for row in stock[1:6]:
    selected.append(row)

# %%
selected
